# %%
import pandas as pd

# %%
df = pd.read_csv('data/zippedData/imdb.title.akas.csv.gz')

# %%
df
# Out:
#          title_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru    NaN
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención    NaN
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
# ...

# %%
df2 = pd.read_csv('data/zippedData/imdb.title.basics.csv.gz')

# %%
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df3 = pd.read_csv('data/zippedData/rotten_tomatoes_movies.csv.gz')

# %%
df3
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 17707                            m/zoot_suit
# 17708                             m/zootopia
# 17709                      m/zorba_the_greek
# 17710                                 m/zulu
# 17711                            m/zulu_dawn
#
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17712 entries, 0 to 17711
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   rotten_tomatoes_link              17712 non-null  object
#  1   movie_title                       17712 non-null  object
#  2   movie_info                        17391 non-null  object
#  3   critics_consensus                 9134 non-null   object
#  4   content_rating                    17712 non-null  object
#  5   genres                            17693 non-null  object
#  6   directors                         17518 non-null  object
#  7   authors                           16170 non-null  object
#  8   actors                            17360 non-null  object
#  9   original_release_date             16546 non-null  object
#  10  streaming_release_date            17328 non-null  object
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17712 entries, 0 to 17711
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   rotten_tomatoes_link              17712 non-null  object
#  1   movie_title                       17712 non-null  object
#  2   movie_info                        17391 non-null  object
#  3   critics_consensus                 9134 non-null   object
#  4   content_rating                    17712 non-null  object
#  5   genres                            17693 non-null  object
#  6   directors                         17518 non-null  object
#  7   authors                           16170 non-null  object
#  8   actors                            17360 non-null  object
#  9   original_release_date             16546 non-null  object
#  10  streaming_release_date            17328 non-null  object
# ...

# %%
df3_0 = df3[['movie_title', 'genres', 'directors', 'tomatometer_rating', 'audience_count']]

# %%
df3_0
# Out:
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 17707                                          Zoot Suit
# 17708                                           Zootopia
# 17709                                    Zorba the Greek
# 17710                                               Zulu
# 17711                                          Zulu Dawn
#
#                                                   genres  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...
# 1                                                 Comedy
# 2                                        Comedy, Romance
# ...

# %%
df3_0.sort_values(by= 'tomatometer_rating', ascending=False, inplace=True)
# Out:
# <ipython-input-12-8ef2087889dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_0.sort_values(by= 'tomatometer_rating', ascending=False, inplace=True)

# %%
df3_0.head(25)
# Out:
#                                             movie_title  \
# 16908                    Vikings: Journey to New Worlds
# 2021                                                 5B
# 17322                  Who the #$&% Is Jackson Pollock?
# 6693                                       Frankenstein
# 12044                                           Primary
# 8727                     John Mulaney: The Comeback Kid
# 8726           John Mulaney: Kid Gorgeous at Radio City
# 14716              The Chronicle of Anna Magdalena Bach
# 875                                                Fury
# 8722          John Leguizamo's Latin History for Morons
# 12966         Scream, Queen! My Nightmare on Elm Street
# 2087    A Bread Factory, Part One: For the Sake of Gold
# 2088    A Bread Factory, Part Two: Walk with Me a While
# 2090                              A Brighter Summer Day
# 5653                                     Dont Look Back
# 2093                                   A Brother's Kiss
# ...

# %%
df3_0.audience_count.mean()
# Out:
# 143940.06833189778

# %%
df3_0.audience_count.median()
# Out:
# 4277.0

# %%
df_aud_count = df3_0.loc[df3_0['audience_count']> 5000]
df_aud_count
# Out:
#                                   movie_title  \
# 5653                           Dont Look Back
# 3654                          Black Narcissus
# 2062   A Bittersweet Life (Dalkomhan insaeng)
# 8786                                   Ju Dou
# 830                                   Henry V
# ...                                       ...
# 8870                                K-9: P.I.
# 10823                        My First Wedding
# 10922         National Lampoon's Gold Diggers
# 7763              The Hills Have Eyes, Part 2
# 16542                        Truth About Love
#
#                                                   genres  \
# 5653   Documentary, Musical & Performing Arts, Specia...
# 3654               Classics, Drama, Faith & Spirituality
# 2062   Action & Adventure, Art House & International,...
# 8786                    Art House & International, Drama
# 830                   Action & Adventure, Drama, Romance
# ...                                                  ...
# ...

# %%
df_aud_count.audience_count.mean()
# Out:
# 301203.45478691295

# %%
df_aud_count.audience_count.median()
# Out:
# 28773.0

# %%
df_aud_count_2 = df_aud_count.sort_values(by= 'audience_count', ascending=False)

# %%
df_aud_count_2.head(50)
# Out:
#                                              movie_title  \
# 16297                                            Titanic
# 15410      The Lord of the Rings: The Return of the King
# 13694                                         Spider-Man
# 13276                                            Shrek 2
# 7526                 Harry Potter and the Goblet of Fire
# 7052                                           Gladiator
# 4579   The Chronicles of Narnia: The Lion, The Witch ...
# 2662                                        American Pie
# 9014                                           King Kong
# 13797       Star Wars: Episode III - Revenge of the Sith
# 10655                                   Mr. & Mrs. Smith
# 701                                                Rocky
# 6453                                        Finding Nemo
# 10183                                         The Matrix
# 2313                          Ace Ventura: Pet Detective
# ...

# %%
df_aud_count_3 =df_aud_count_2.head(1000)

# %%
df_aud_count_3.sort_values(by= 'tomatometer_rating', ascending=False)
# Out:
#                movie_title                                             genres  \
# 10156         Mary Poppins  Classics, Comedy, Kids & Family, Musical & Per...
# 16406          Toy Story 2                   Animation, Comedy, Kids & Family
# 11852            Pinocchio  Animation, Kids & Family, Musical & Performing...
# 14336       The Terminator      Action & Adventure, Science Fiction & Fantasy
# 16405            Toy Story                   Animation, Comedy, Kids & Family
# ...                    ...                                                ...
# 7179       Good Luck Chuck                                             Comedy
# 1510   Big Momma's House 2                                             Comedy
# 4924          The Covenant                         Horror, Mystery & Suspense
# 3327     Because I Said So                             Comedy, Drama, Romance
# 6054            Epic Movie                         Action & Adventure, Comedy
#
# ...

# %%
#df_aud_count_3.genres.head(25).describe()

# %%
df_aud_count_3['genres'] = df_aud_count_3['genres'].str.split(",")
df_aud_count_3
# Out:
# <ipython-input-24-a72132931d2c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aud_count_3['genres'] = df_aud_count_3['genres'].str.split(",")
#                                          movie_title  \
# 16297                                        Titanic
# 15410  The Lord of the Rings: The Return of the King
# 13694                                     Spider-Man
# 13276                                        Shrek 2
# 7526             Harry Potter and the Goblet of Fire
# ...                                              ...
# 11659                                    Patch Adams
# 12615                                     Robin Hood
# 10125                                    Marley & Me
# ...

# %%
def is_genre(genres):
    if 'Action & Adventure' in genres:
        return True;
    else:
        return False;

df_aud_count_3['Is_A&A'] = df_aud_count_3['genres'].apply(is_genre)
df_aud_count_3.head()
# Out:
# <ipython-input-29-1a658a7f1fce>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aud_count_3['Is_A&A'] = df_aud_count_3['genres'].apply(is_genre)
#                                          movie_title  \
# 16297                                        Titanic
# 15410  The Lord of the Rings: The Return of the King
# 13694                                     Spider-Man
# 13276                                        Shrek 2
# 7526             Harry Potter and the Goblet of Fire
#
#                                                   genres  \
# 16297                                  [Drama,  Romance]
# 15410  [Action & Adventure,  Classics,  Science Ficti...
# 13694  [Action & Adventure,  Mystery & Suspense,  Sci...
# ...

# %%
df_aud_count_3['Is_A&A'].sum()
# Out:
# 410

# %%
#df_aud_count_3['genres'] = df_aud_count_3.explode(df_aud_count_3['genres'])

# %%
#df_aud_count_3

# %%
#df_aud_count_3.explode(df_aud_count_3['genres'])
